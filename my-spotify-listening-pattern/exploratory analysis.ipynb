# %%
import pandas as pd
import numpy as np
import json

# %%
path = "my_spotify_data/Spotify Extended Streaming History/Streaming_History_Audio_2023-2025_3.json"

with open(path, 'r') as file:
    data = json.load(file)

history = pd.DataFrame(data)
history.head()
# Out:
#                      ts platform  ms_played conn_country         ip_addr  \
# 0  2023-12-13T07:22:51Z      ios     165900           US  161.97.208.195
# 1  2023-12-13T07:25:38Z      ios     165900           US  161.97.208.195
# 2  2023-12-13T07:28:24Z      ios     165900           US  161.97.208.195
# 3  2023-12-13T07:31:10Z      ios     165900           US  161.97.208.195
# 4  2023-12-13T07:33:57Z      ios     165900           US  161.97.208.195
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                    Snowman                               Sia
# 1                    Snowman                               Sia
# 2                    Snowman                               Sia
# 3                    Snowman                               Sia
# 4                    Snowman                               Sia
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# 0            Everyday Is Christmas  spotify:track:7uoFMmxln0GPXQ0AcCBXRq
# 1            Everyday Is Christmas  spotify:track:7uoFMmxln0GPXQ0AcCBXRq
# 2            Everyday Is Christmas  spotify:track:7uoFMmxln0GPXQ0AcCBXRq
# 3            Everyday Is Christmas  spotify:track:7uoFMmxln0GPXQ0AcCBXRq
# 4            Everyday Is Christmas  spotify:track:7uoFMmxln0GPXQ0AcCBXRq
#
#   episode_name  ... audiobook_uri audiobook_chapter_uri  \
# 0         None  ...          None                  None
# 1         None  ...          None                  None
# 2         None  ...          None                  None
# 3         None  ...          None                  None
# 4         None  ...          None                  None
#
#   audiobook_chapter_title reason_start reason_end shuffle skipped offline  \
# 0                    None    trackdone  trackdone   False   False   False
# 1                    None    trackdone  trackdone   False   False   False
# 2                    None    trackdone  trackdone   False   False   False
# 3                    None    trackdone  trackdone   False   False   False
# 4                    None    trackdone  trackdone   False   False   False
#
#    offline_timestamp  incognito_mode
# 0       1.702452e+09           False
# 1       1.702452e+09           False
# 2       1.702452e+09           False
# 3       1.702453e+09           False
# 4       1.702453e+09           False
#
# [5 rows x 23 columns]

# %%
history.columns
# Out:
# Index(['ts', 'platform', 'ms_played', 'conn_country', 'ip_addr',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'audiobook_title',
#        'audiobook_uri', 'audiobook_chapter_uri', 'audiobook_chapter_title',
#        'reason_start', 'reason_end', 'shuffle', 'skipped', 'offline',
#        'offline_timestamp', 'incognito_mode'],
#       dtype='object')

# %%
new_colnames = ['ts', 'platform', 'ms_played', 'conn_country', 'ip_addr',
       'track_name', 'master_metadata_album_artist_name',
       'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
       'episode_show_name', 'spotify_episode_uri', 'audiobook_title',
       'audiobook_uri', 'audiobook_chapter_uri', 'audiobook_chapter_title',
       'reason_start', 'reason_end', 'shuffle', 'skipped', 'offline',
       'offline_timestamp', 'incognito_mode']
